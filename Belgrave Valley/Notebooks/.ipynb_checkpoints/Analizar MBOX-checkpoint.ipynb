# %%
import mailbox
import bs4
import email
from email import message


def get_html_text(html):
    return bs4.BeautifulSoup(html, 'lxml').body.get_text(' ', strip=True)

def read_email_text(msg):
    content_type = 'NA' if isinstance(msg, str) else msg.get_content_type()
    encoding = 'NA' if isinstance(msg, str) else msg.get('Content-Transfer-Encoding')
    if 'text/plain' in content_type and 'base64' not in encoding:
        msg_text = msg.get_payload()
    elif 'text/html' in content_type and 'base64' not in encoding:
        msg_text = get_html_text(msg.get_payload())
    elif content_type == 'NA':
        msg_text = het_html_text(msg)
    else:
        msg_text = None
    return (content_type, encoding, msg_text)

def get_email_messages(email_payload):
    for msg in email_payload:
        if isinstance(msg, (list,tuple)):
            for submsg in get_email_messages(msg):
                yield submsg
        elif msg.is_multipart():
            for submsg in get_email_messages(msg.get_payload()):
                yield submsg
        else:
            yield msg

def read_email_payload(email_data):
    email_payload = email_data.get_payload()
    if email_data.is_multipart():
        email_messages = list(get_email_messages(email_payload))
    else:
        email_messages = [email_payload]
    return [read_email_text(msg) for msg in email_messages]

def parse_email(email_data):
    email_labels = email_data['X-Gmail-Labels']
    email_date = email_data['Date']
    email_from = email_data['From']
    email_to = email_data['To']
    email_subject = email_data['Subject']
    email_text = read_email_payload(email_data) 

mbox_data = mailbox.mbox('/Users/Javi/Downloads/Destacados.mbox')

num_entries = len(mbox_data)

for idx, email_data in enumerate(mbox_data):
    print('Parsing email {0} of {1}'.format(idx, num_entries))
# Out:
# Parsing email 0 of 4
# Parsing email 1 of 4
# Parsing email 2 of 4
# Parsing email 3 of 4

# %%
for i in list(range(len(mbox_data))):
    print(mbox_data[i]["To"])
    
for i in list(range(len(mbox_data))):
    print(mbox_data[i]["Subject"])
    
for i in list(range(len(mbox_data))):
    print(mbox_data[i]["From"])
    
for i in list(range(len(mbox_data))):
    print(mbox_data[i]["Date"])
# Out:
# alessiobunsetti@gmail.com
# alessiobunsetti@gmail.com
# alessiobunsetti@gmail.com
# alessiobunsetti@gmail.com
# Fwd: 105
# Fwd: 105
# Fwd: 105
# Fwd: 105
# Javier Chamorro <javier.chamorro.w@gmail.com>
# Javier Chamorro <javier.chamorro.w@gmail.com>
# Javier Chamorro <javier.chamorro.w@gmail.com>
# Javier Chamorro <javier.chamorro.w@gmail.com>
# Fri, 5 Nov 2021 16:08:16 +0100
# Fri, 5 Nov 2021 16:08:35 +0100
# Fri, 5 Nov 2021 16:08:26 +0100
# Fri, 5 Nov 2021 12:45:34 +0100

# %%
import mailbox
import quopri,base64
import pandas as pd
import email
import mailbox
import bs4
from email import message

def myconvert(encoded,ContentTransferEncoding):
    if ContentTransferEncoding == 'quoted-printable':
        result = quopri.decodestring(encoded)
    elif ContentTransferEncoding == 'base64':
        result = base64.b64decode(encoded)

mboxfile = '/Users/Javi/Downloads/Destacados.mbox'

body_list = []

for msg in mailbox.mbox(mboxfile):
    if msg.is_multipart():    #Walk through the parts of the email to find the text body.
        for part in msg.walk():
            if part.is_multipart(): # If part is multipart, walk through the subparts.
                for subpart in part.walk():
                    if subpart.get_content_type() == 'text/plain':
                        body = subpart.get_payload(decode=False) # Get the subpart payload (i.e the message body)
                        body_list.append(body)
                    for k,v in subpart.items():
                            if k == 'Content-Transfer-Encoding':
                                cte = v             # Keep the Content Transfer Encoding
            elif subpart.get_content_type() == 'text/plain':
                body = part.get_payload(decode=False)           # part isn't multipart Get the payload
                for k,v in part.items():
                    if k == 'Content-Transfer-Encoding':
                        cte = v                      # Keep the Content Transfer Encoding

#print(body)
#print('Body is of type:',type(body))
#body = myconvert(body,cte)
#print(body)
body_list[3]
# Out:
# '---------- Forwarded message ---------\r\nDe: Sales Team sellyourtesla.de <ankauf@sellyourtesla.de>\r\nDate: vie, 5 nov 2021 a las 12:39\r\nSubject: Fwd: 105\r\nTo: javier.chamorro.w@gmail.com <javier.chamorro.w@gmail.com>\r\n\r\n\r\n\r\n---------- Urspr=C3=BCngliche Nachricht ----------\r\nVon: Justin Breschul <justin@gmail.com>\r\nAn: ankauf@sellyourtesla.de\r\nDatum: 29.10.2021 11:19\r\nBetreff: 105\r\n\r\n\r\n*Welches Tesla Modell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.de\r\n'

# %% [markdown]
# import email

# %% [markdown]
# .get_payload

# %% [markdown]
# for i in list(range(len(mbox_data))):
#     print(mbox_data[i]["Body"])

# %%
print(mboxfile)
# Out:
# /Users/Javi/Downloads/Destacados.mbox

# %% [markdown]
# yy = []
#
# for body in body_list:
#     yy.append(body)
# index = yy.find("Welches")
# new_yy = yy[index:]
# new_yy

# %% [markdown]
# yy = body_list[0]
# index = yy.find("Welches")
# new_yy = yy[index:]
# new_yy

# %%
body_prueba = []
for i, b in enumerate(body_list):
    index = body_list[i].find("Welches")
    new_yy = body_list[i][index:]
    body_prueba.append(new_yy)

body_prueba
# Out:
# ['Welches Tesla Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n6363636366\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 11252 (0 min / 12000 max)\r\n*Antriebsversion*\r\nMaximale Reichweite\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nVolles Potential f=C3=BCr autonomes Fahren\r\n*Unfallfahrzeug:*\r\nJa\r\n*Brutto-Listenpreis*\r\n999999\r\n*Name*\r\nhhh ddd\r\n*Strasse und Hausnummer*\r\nddd\r\n*PLZ und Ort*\r\nddd\r\n*Telefonische Erreichbarkeit*\r\n010101100101\r\n*E-Mail*\r\nhhhh@hhhh.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankaufs AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.de\r\n',
#  'Welches Tesla Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n16.5.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)\r\n*Antriebsversion*\r\nMaximale Reichweite\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nNein\r\n*Brutto-Listenpreis*\r\n55000\r\n*Name*\r\nG=C3=BCnter Meisinger\r\n*Strasse und Hausnummer*\r\n94116 Hutthurm\r\n*PLZ und Ort*\r\nHutthurm\r\n*Telefonische Erreichbarkeit*\r\n015115617854\r\n*E-Mail*\r\ng.meisinger@mlogica.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.de\r\n',
#  'Welches Tesla Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n21.04.2020\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)\r\n*Antriebsversion*\r\nStandard Plus\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nJa\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Zubeh=C3=B6r*\r\nAnh=C3=A4ngerkupplung\r\n*Brutto-Listenpreis*\r\nTest\r\n*Name*\r\nTest Test\r\n*Strasse und Hausnummer*\r\nTest\r\n*PLZ und Ort*\r\nTest\r\n*Telefonische Erreichbarkeit*\r\n28971309827\r\n*E-Mail*\r\ntest@test.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.de\r\n',
#  'Welches Tesla Modell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.de\r\n']

# %% [markdown]
# body_xxx = []
# for b in body_list:
#     index = yy.find("Welches")
#     new_yy = yy[index:]
#     body_xxx.append(new_yy)

# %%
questions_first = ['Welches', 'Ausweisbare', 'Datum', 'Kilometerstand', 'Antriebsversion', 'Lackierungen', 'R=C3=A4der', 'Innenansicht','Autopilot','Unfallfahrzeug:', 'Brutto', 'Name', 'Strasse', 'PLZ','Telefonische', 'E-Mail', 'Datenschutzerkl=C3=A4rung', 'Ankaufs AGB']
questions_second = ['Ausweisbare', 'Datum', 'Kilometerstand', 'Antriebsversion', 'Lackierungen', 'R=C3=A4der', 'Innenansicht','Autopilot','Unfallfahrzeug:', 'Brutto', 'Name', 'Strasse', 'PLZ','Telefonische', 'E-Mail', 'Datenschutzerkl=C3=A4rung', 'Ankaufs AGB', '-1']

# %%
len_question_1 = len('Welches Tesla Modell m=C3=B6chtest Du verkaufen?')
len_question_2 = len('Ausweisbare MWST?')
len_question_3 = len('Datum der Erstzulassung')
len_question_4 = len('Kilometerstand')
len_question_5 = len('Antriebsversion')
len_question_6 = len('Lackierungen')
len_question_7 = len('R=C3=A4der')
len_question_8 = len('Innenansicht')
len_question_9 = len('Autopilot')
len_question_10 = len('Unfallfahrzeug:')
len_question_11 = len('Brutto-Listenpreis')
len_question_18 = len('Name')
len_question_12 = len('Strasse und Hausnummer')
len_question_13 = len('PLZ und Ort')
len_question_14 = len('Telefonische Erreichbarkeit')
len_question_15 = len('E-Mail')
len_question_16 = len('Datenschutzerkl=C3=A4rung')
len_question_17 = len('Ankaufs AGB')

variab_lq = [len_question_1, len_question_2, len_question_3, len_question_4, len_question_5, len_question_6,len_question_7,len_question_8,len_question_9,len_question_10,len_question_11,len_question_18,len_question_12,len_question_13,len_question_14,len_question_15,len_question_16,len_question_17]

question_1 = new_yy[:len_question_1]
question_1


answer_1 = [len_question_1 + 4]

variab_lq
# Out:
# [48, 17, 23, 14, 15, 12, 10, 12, 9, 15, 18, 4, 22, 11, 27, 6, 25, 11]

# %%
answers_list = []
pyr = []
ryp = []
for j, bx in enumerate(body_prueba):
    
    questions = []
    answers = []
    for i, x, s in zip(variab_lq, questions_first, questions_second):
        index = bx.find(x)
        index_plus_one = bx.find(s)
        question = bx[index:(i+index)]
        questions.append(question)
        answer = bx[(index+i):(index_plus_one)]
        answers.append(answer[3:-3])
    answers_list.append(answers)
answers_list
# Out:
# [['Model 3',
#   'Ja',
#   '6363636366',
#   'Ausgew=C3=A4hlter Wert: 11252 (0 min / 12000 max)',
#   'Maximale Reichweite',
#   'Red Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Volles Potential f=C3=BCr autonomes Fahren',
#   'Ja',
#   '999999',
#   'hhh ddd',
#   'ddd',
#   'ddd',
#   '010101100101',
#   'hhhh@hhhh.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model 3',
#   'Ja',
#   '16.5.2021',
#   'Ausgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)',
#   'Maximale Reichweite',
#   'Pearl White Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Basis',
#   'Nein',
#   '55000',
#   'G=C3=BCnter Meisinger',
#   '94116 Hutthurm',
#   'Hutthurm',
#   '015115617854',
#   'g.meisinger@mlogica.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n16.5.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)\r\n*Antriebsversion*\r\nMaximale Reichweite\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nNein\r\n*Brutto-Listenpreis*\r\n55000\r\n*Name*\r\nG=C3=BCnter Meisinger\r\n*Strasse und Hausnummer*\r\n94116 Hutthurm\r\n*PLZ und Ort*\r\nHutthurm\r\n*Telefonische Erreichbarkeit*\r\n015115617854\r\n*E-Mail*\r\ng.meisinger@mlogica.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model 3',
#   'Ja',
#   '21.04.2020',
#   'Ausgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)',
#   'Standard Plus',
#   'Pearl White Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Basis',
#   'Ja\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Zubeh=C3=B6r*\r\nAnh=C3=A4ngerkupplung',
#   'Test',
#   'Test Test',
#   'Test',
#   'Test',
#   '28971309827',
#   'test@test.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n21.04.2020\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)\r\n*Antriebsversion*\r\nStandard Plus\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nJa\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Zubeh=C3=B6r*\r\nAnh=C3=A4ngerkupplung\r\n*Brutto-Listenpreis*\r\nTest\r\n*Name*\r\nTest Test\r\n*Strasse und Hausnummer*\r\nTest\r\n*PLZ und Ort*\r\nTest\r\n*Telefonische Erreichbarkeit*\r\n28971309827\r\n*E-Mail*\r\ntest@test.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model Y',
#   'Ja',
#   '09.10.2021',
#   'Ausgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)',
#   'Performance',
#   'Red Multi-Coat',
#   'Model Y - 20" Induction Felgen',
#   'Schwarz und wei=C3=9F',
#   'Enhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   'ell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced',
#   'Justin Breschul',
#   'Sonderschulstrasse 1',
#   '42105 Wuppertal',
#   '0189765432',
#   'justin@gmail.com',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.']]

# %%
questions = []
answers = []
for i, x, s in zip(variab_lq, questions_first, questions_second):
    index = new_yy.find(x)
    index_plus_one = new_yy.find(s)
    #print(index)
    question = new_yy[index:(i+index)]
    #print(question)
    questions.append(question)
    answer = new_yy[(index+i):(index_plus_one)]
    #print(answer[3:-3])
    answers.append(answer[3:-3])
    #result = yy[index:(index+variab_lq)]
    #pyr.append(result)
answers
# Out:
# ['Model Y',
#  'Ja',
#  '09.10.2021',
#  'Ausgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)',
#  'Performance',
#  'Red Multi-Coat',
#  'Model Y - 20" Induction Felgen',
#  'Schwarz und wei=C3=9F',
#  'Enhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#  'ell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#  ' m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced',
#  'Justin Breschul',
#  'Sonderschulstrasse 1',
#  '42105 Wuppertal',
#  '0189765432',
#  'justin@gmail.com',
#  'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#  ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.']

# %%
pyr = []
ryp = []
for i, x, s in zip(variab_lq, questions_first, questions_second):
    index = new_yy.find(x)
    index_plus_one = new_yy.find(s)
    #print(index)
    question = new_yy[index:(i+index)]
    #print(question)
    pyr.append(question)
    remainder = new_yy[(index+i):(index_plus_one)]
    #print(remainder[3:-3])
    ryp.append(remainder[3:-3])
    #result = yy[index:(index+variab_lq)]
    #pyr.append(result)
#pyr

# %% [markdown]
# for r in ryp:
#     print(r[3:-3])

# %%
questions
# Out:
# ['Welches Tesla Modell m=C3=B6chtest Du verkaufen?',
#  'Ausweisbare MWST?',
#  'Datum der Erstzulassung',
#  'Kilometerstand',
#  'Antriebsversion',
#  'Lackierungen',
#  'R=C3=A4der',
#  'Innenansicht',
#  'Autopilot',
#  '',
#  '',
#  'Name',
#  'Strasse und Hausnummer',
#  'PLZ und Ort',
#  'Telefonische Erreichbarkeit',
#  'E-Mail',
#  'Datenschutzerkl=C3=A4rung',
#  '']

# %%
answers_list
# Out:
# [['Model 3',
#   'Ja',
#   '6363636366',
#   'Ausgew=C3=A4hlter Wert: 11252 (0 min / 12000 max)',
#   'Maximale Reichweite',
#   'Red Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Volles Potential f=C3=BCr autonomes Fahren',
#   'Ja',
#   '999999',
#   'hhh ddd',
#   'ddd',
#   'ddd',
#   '010101100101',
#   'hhhh@hhhh.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model 3',
#   'Ja',
#   '16.5.2021',
#   'Ausgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)',
#   'Maximale Reichweite',
#   'Pearl White Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Basis',
#   'Nein',
#   '55000',
#   'G=C3=BCnter Meisinger',
#   '94116 Hutthurm',
#   'Hutthurm',
#   '015115617854',
#   'g.meisinger@mlogica.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n16.5.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)\r\n*Antriebsversion*\r\nMaximale Reichweite\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nNein\r\n*Brutto-Listenpreis*\r\n55000\r\n*Name*\r\nG=C3=BCnter Meisinger\r\n*Strasse und Hausnummer*\r\n94116 Hutthurm\r\n*PLZ und Ort*\r\nHutthurm\r\n*Telefonische Erreichbarkeit*\r\n015115617854\r\n*E-Mail*\r\ng.meisinger@mlogica.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model 3',
#   'Ja',
#   '21.04.2020',
#   'Ausgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)',
#   'Standard Plus',
#   'Pearl White Multi-Coat',
#   'Model 3 - 18" Aero Felgen',
#   'Komplett schwarz',
#   'Basis',
#   'Ja\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Zubeh=C3=B6r*\r\nAnh=C3=A4ngerkupplung',
#   'Test',
#   'Test Test',
#   'Test',
#   'Test',
#   '28971309827',
#   'test@test.de',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel 3\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n21.04.2020\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)\r\n*Antriebsversion*\r\nStandard Plus\r\n*Lackierungen*\r\nPearl White Multi-Coat\r\n*R=C3=A4der*\r\nModel 3 - 18" Aero Felgen\r\n*Innenansicht*\r\nKomplett schwarz\r\n*Autopilot*\r\nBasis\r\n*Unfallfahrzeug:*\r\nJa\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Zubeh=C3=B6r*\r\nAnh=C3=A4ngerkupplung\r\n*Brutto-Listenpreis*\r\nTest\r\n*Name*\r\nTest Test\r\n*Strasse und Hausnummer*\r\nTest\r\n*PLZ und Ort*\r\nTest\r\n*Telefonische Erreichbarkeit*\r\n28971309827\r\n*E-Mail*\r\ntest@test.de\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\n*Ankauf AGB*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Ankauf AGB gelesen ha=\r\nbe\r\nund akzeptiere.\r\nGesendet von sellyourtesla.'],
#  ['Model Y',
#   'Ja',
#   '09.10.2021',
#   'Ausgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)',
#   'Performance',
#   'Red Multi-Coat',
#   'Model Y - 20" Induction Felgen',
#   'Schwarz und wei=C3=9F',
#   'Enhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   'ell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced',
#   'Justin Breschul',
#   'Sonderschulstrasse 1',
#   '42105 Wuppertal',
#   '0189765432',
#   'justin@gmail.com',
#   'Hiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.',
#   ' Modell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*Ausweisbare MWST?*\r\nJa\r\n*Datum der Erstzulassung*\r\n09.10.2021\r\n*Kilometerstand*\r\nAusgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)\r\n*Antriebsversion*\r\nPerformance\r\n*Lackierungen*\r\nRed Multi-Coat\r\n*R=C3=A4der*\r\nModel Y - 20" Induction Felgen\r\n*Innenansicht*\r\nSchwarz und wei=C3=9F\r\n*Autopilot*\r\nEnhanced\r\n*Name*\r\nJustin Breschul\r\n*Strasse und Hausnummer*\r\nSonderschulstrasse 1\r\n*PLZ und Ort*\r\n42105 Wuppertal\r\n*Telefonische Erreichbarkeit*\r\n0189765432\r\n*E-Mail*\r\njustin@gmail.com\r\n*Datenschutzerkl=C3=A4rung*\r\nHiermit best=C3=A4tige ich, dass ich die nachfolgende Datenschutzerkl=C3=A4=\r\nrung\r\ngelesen habe und akzeptiere.\r\nGesendet von sellyourtesla.']]

# %%
df_t = pd.DataFrame(answers_list)
df_t
# Out:
#         0   1           2                                                  3   \
# 0  Model 3  Ja  6363636366  Ausgew=C3=A4hlter Wert: 11252 (0 min / 12000 max)
# 1  Model 3  Ja   16.5.2021   Ausgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)
# 2  Model 3  Ja  21.04.2020   Ausgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)
# 3  Model Y  Ja  09.10.2021   Ausgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)
#
#                     4                       5   \
# 0  Maximale Reichweite          Red Multi-Coat
# 1  Maximale Reichweite  Pearl White Multi-Coat
# 2        Standard Plus  Pearl White Multi-Coat
# 3          Performance          Red Multi-Coat
#
#                                6                      7   \
# 0       Model 3 - 18" Aero Felgen       Komplett schwarz
# 1       Model 3 - 18" Aero Felgen       Komplett schwarz
# 2       Model 3 - 18" Aero Felgen       Komplett schwarz
# 3  Model Y - 20" Induction Felgen  Schwarz und wei=C3=9F
#
#                                                   8   \
# 0         Volles Potential f=C3=BCr autonomes Fahren
# 1                                              Basis
# 2                                              Basis
# 3  Enhanced\r\n*Name*\r\nJustin Breschul\r\n*Stra...
#
#                                                   9   \
# 0                                                 Ja
# 1                                               Nein
# 2  Ja\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Z...
# 3  ell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\...
#
#                                                   10                     11  \
# 0                                             999999                hhh ddd
# 1                                              55000  G=C3=BCnter Meisinger
# 2                                               Test              Test Test
# 3   m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*A...        Justin Breschul
#
#                      12               13            14  \
# 0                   ddd              ddd  010101100101
# 1        94116 Hutthurm         Hutthurm  015115617854
# 2                  Test             Test   28971309827
# 3  Sonderschulstrasse 1  42105 Wuppertal    0189765432
#
#                        15                                                 16  \
# 0            hhhh@hhhh.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 1  g.meisinger@mlogica.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 2            test@test.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 3        justin@gmail.com  Hiermit best=C3=A4tige ich, dass ich die nachf...
#
#                                                   17
# 0  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 1   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...
# 2   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...
# 3   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...

# %%
df_t.columns=questions
df_t
# Out:
#   Welches Tesla Modell m=C3=B6chtest Du verkaufen? Ausweisbare MWST?  \
# 0                                          Model 3                Ja
# 1                                          Model 3                Ja
# 2                                          Model 3                Ja
# 3                                          Model Y                Ja
#
#   Datum der Erstzulassung                                     Kilometerstand  \
# 0              6363636366  Ausgew=C3=A4hlter Wert: 11252 (0 min / 12000 max)
# 1               16.5.2021   Ausgew=C3=A4hlter Wert: 9429 (0 min / 12000 max)
# 2              21.04.2020   Ausgew=C3=A4hlter Wert: 2847 (0 min / 12000 max)
# 3              09.10.2021   Ausgew=C3=A4hlter Wert: 1432 (0 min / 12000 max)
#
#        Antriebsversion            Lackierungen  \
# 0  Maximale Reichweite          Red Multi-Coat
# 1  Maximale Reichweite  Pearl White Multi-Coat
# 2        Standard Plus  Pearl White Multi-Coat
# 3          Performance          Red Multi-Coat
#
#                        R=C3=A4der           Innenansicht  \
# 0       Model 3 - 18" Aero Felgen       Komplett schwarz
# 1       Model 3 - 18" Aero Felgen       Komplett schwarz
# 2       Model 3 - 18" Aero Felgen       Komplett schwarz
# 3  Model Y - 20" Induction Felgen  Schwarz und wei=C3=9F
#
#                                            Autopilot  \
# 0         Volles Potential f=C3=BCr autonomes Fahren
# 1                                              Basis
# 2                                              Basis
# 3  Enhanced\r\n*Name*\r\nJustin Breschul\r\n*Stra...
#
#                                                       \
# 0                                                 Ja
# 1                                               Nein
# 2  Ja\r\n*Besch=C3=A4digungen*\r\nTest Test\r\n*Z...
# 3  ell m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\...
#
#                                                                        Name  \
# 0                                             999999                hhh ddd
# 1                                              55000  G=C3=BCnter Meisinger
# 2                                               Test              Test Test
# 3   m=C3=B6chtest Du verkaufen?*\r\nModel Y\r\n*A...        Justin Breschul
#
#   Strasse und Hausnummer      PLZ und Ort Telefonische Erreichbarkeit  \
# 0                    ddd              ddd                010101100101
# 1         94116 Hutthurm         Hutthurm                015115617854
# 2                   Test             Test                 28971309827
# 3   Sonderschulstrasse 1  42105 Wuppertal                  0189765432
#
#                    E-Mail                          Datenschutzerkl=C3=A4rung  \
# 0            hhhh@hhhh.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 1  g.meisinger@mlogica.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 2            test@test.de  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 3        justin@gmail.com  Hiermit best=C3=A4tige ich, dass ich die nachf...
#
#
# 0  Hiermit best=C3=A4tige ich, dass ich die nachf...
# 1   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...
# 2   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...
# 3   Modell m=C3=B6chtest Du verkaufen?*\r\nModel ...

# %% [markdown]
# df_t = pd.DataFrame(answers_list)
# df_t

# %% [markdown]
# df = pd.DataFrame(questions, answers_list)
# df_t = pd.DataFrame(questions, answers_list).transpose()
# df_t

# %% [markdown]
# df = pd.DataFrame(pyr,ryp)
# df_t = pd.DataFrame(ryp, pyr).transpose()
# df_t

# %% [markdown]
# for i in new_yy:

# %%
body_list[0].find('n*')
# Out:
# 584

# %% [markdown]
# xx = pd.read_csv(yy, sep = '\r\n')
# xx

# %% [markdown]
# def read_email_payload_2(email_data):
#     email_payload = email_data.email.message.Message.get_payload()
#     if email_data.is_multipart():
#         email_messages = list(get_email_messages(email_payload))
#     else:
#         email_messages = [email_payload]
#     return [read_email_text(msg) for msg in email_messages]

# %% [markdown]
# def parse_email_2(email_data):
#     for i, email_data in zip(range(num_entries), email_data):
#         #email_labels = email_data[i]['X-Gmail-Labels']
#         email_date = email_data[i]['Date']
#         email_from = email_data[i]['From']
#         email_to = email_data[i]['To']
#         email_subject = email_data[i]['Subject']
#         email_text = read_email_payload(email_data)

# %% [markdown]
# import mailbox
# import bs4
#
# def get_html_text(html):
#     try:
#         return bs4.BeautifulSoup(html, 'lxml').body.get_text(' ', strip=True)
#     except AttributeError: # message contents empty
#         return None
#
# class GmailMboxMessage():
#     def __init__(self, email_data):
#         if not isinstance(email_data, mailbox.mboxMessage):
#             raise TypeError('Variable must be type mailbox.mboxMessage')
#         self.email_data = email_data
#
#     def parse_email(self):
#         email_labels = self.email_data['X-Gmail-Labels']
#         email_date = self.email_data['Date']
#         email_from = self.email_data['From']
#         email_to = self.email_data['To']
#         email_subject = self.email_data['Subject']
#         email_text = self.read_email_payload()
#
#     def read_email_payload(self):
#         email_payload = self.email_data.get_payload()
#         if self.email_data.is_multipart():
#             email_messages = list(self._get_email_messages(email_payload))
#         else:
#             email_messages = [email_payload]
#         return [self._read_email_text(msg) for msg in email_messages]
#
#     def _get_email_messages(self, email_payload):
#         for msg in email_payload:
#             if isinstance(msg, (list,tuple)):
#                 for submsg in self._get_email_messages(msg):
#                     yield submsg
#             elif msg.is_multipart():
#                 for submsg in self._get_email_messages(msg.get_payload()):
#                     yield submsg
#             else:
#                 yield msg
#
#     def _read_email_text(self, msg):
#         content_type = 'NA' if isinstance(msg, str) else msg.get_content_type()
#         encoding = 'NA' if isinstance(msg, str) else msg.get('Content-Transfer-Encoding', 'NA')
#         if 'text/plain' in content_type and 'base64' not in encoding:
#             msg_text = msg.get_payload()
#         elif 'text/html' in content_type and 'base64' not in encoding:
#             msg_text = get_html_text(msg.get_payload())
#         elif content_type == 'NA':
#             msg_text = get_html_text(msg)
#         else:
#             msg_text = None
#         return (content_type, encoding, msg_text)
#
# ######################### End of library, example of use below
#
# mbox_obj = mailbox.mbox('/Users/Javi/Downloads/Destacados.mbox')
#
# num_entries = len(mbox_obj)
#
# for idx, email_obj in enumerate(mbox_obj):
#     email_data = GmailMboxMessage(email_obj)
#     email_data.parse_email()
#     print('Parsing email {0} of {1}'.format(idx, num_entries))
